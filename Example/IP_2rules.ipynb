# %%
import cvxpy as cp
import numpy as np

# given parameters
m = 0.22;
M = 1.3282;
f0 = 22.915;
f1 = 0.007056;
l = 0.304;
J = 0.004963;
g = 9.8;

# determined domain
p1 = 0
p2 = (np.pi/180)*85

n_r = 2  # number of rules rule 1: x1 = p1, rule 2: x1 = p2
n_s = 4  # size of A[i] matrix
n_u = 1  # size of B[i] matrix

# Define A and B matrices
A = []
B = []
a = (M+m)*(J+m*l**2) - (m**2*l**2);
a21 = (M+m)*m*g*(l/a);
a22 = -f1*(M+m)/a;
a24 = f0*m*(l/a);
a41 = -m**2*g*(l**2/a);
a42 = f1*m*(l/a);
a44 = -f0*(J+m*l**2)/a;
b2 = -m*(l/a);
b4 = (J+m*l**2)/a;
ad = (M+m)*(J+m*l**2)-m**2*l**2*np.cos(p2)**2
a21d = (np.sin(p2)/p2)*(M+m)*m*g*(l/ad)
a22d = -f1*(M+m)/ad
a24d = f0*m*l*np.cos(p2)/ad
a41d = -(np.sin(p2)*np.cos(p2)/p2)*((m**2*g*l**2)/ad)
a42d = f1*m*l*np.cos(p2)/ad
a44d = -f0*((J+m*l**2)/ad)
b2d = -m*l*np.cos(p2)/ad
b4d = (J+m*l**2)/ad

A.append(np.array([[0, 1, 0, 0],
                  [a21, a22, 0, a24],
                  [0, 0, 0, 1],
                  [a41, a42, 0, a44]]))
B.append(np.array([[0],
                [b2],
                [0],
                [b4]]))

A.append(np.array([[0, 1, 0, 0],
                  [a21d, a22d, 0, a24d],
                  [0, 0, 0, 1],
                  [a41d, a42d, 0, a44d]]))

B.append(np.array([[0],
                [b2d],
                [0],
                [b4d]]))

# decision variables
Q = cp.Variable((n_s, n_s), symmetric=True)
Y = [cp.Variable((n_u, n_s)) for _ in range(n_r)]
I = np.identity(n_s)
#gamma = cp.Variable((1, 1))
# LMI constraints
constraints = []

# LMI condition for stabilization of each sub system
for i in range(n_r):
    Ai = A[i]
    Bi = B[i]
    constraints.append((Ai @ Q + Q @ Ai.T + Bi @ Y[i] + Y[i].T @ Bi.T) << 0)

# LMI condition for stabilization of joint systems (refer [1])
# case 1
for j in range(1, n_r):
    Ai = A[0]
    Aj = A[j]
    Bi = B[0]
    Bj = B[j]
    constraint_lhs = (Ai @ Q + Q @ Ai.T + Bi @ Y[j] + Y[j].T @ Bi.T) / 2
    constraint_rhs = (Aj @ Q + Q @ Aj.T + Bj @ Y[0] + Y[0].T @ Bj.T) / 2
    constraints.append(constraint_lhs + constraint_rhs << 0)

# case 2
for j in range(2, n_r):
    Ai = A[1]
    Aj = A[j]
    Bi = B[1]
    Bj = B[j]
    constraint_lhs = (Ai @ Q + Q @ Ai.T + Bi @ Y[j] + Y[j].T @ Bi.T) / 2
    constraint_rhs = (Aj @ Q + Q @ Aj.T + Bj @ Y[1] + Y[1].T @ Bj.T) / 2
    constraints.append(constraint_lhs + constraint_rhs << 0)

# case 3
for j in range(3, n_r):
    Ai = A[2]
    Aj = A[j]
    Bi = B[2]
    Bj = B[j]
    constraint_lhs = (Ai @ Q + Q @ Ai.T + Bi @ Y[j] + Y[j].T @ Bi.T) / 2
    constraint_rhs = (Aj @ Q + Q @ Aj.T + Bj @ Y[2] + Y[2].T @ Bj.T) / 2
    constraints.append(constraint_lhs + constraint_rhs << 0)

# Positive semidefinite constraint on Q
constraints.append(Q - 0.1*I>> 0) # 0.1 is for avoiding numerical problems

problem = cp.Problem(cp.Minimize(0), constraints)
print(problem.is_qp())
problem.solve(verbose = True)  # you can choose SDP solvers (recommend "SCS" solver)


ch = [c.dual_value for c in constraints]

K = [Y[i].value @ np.linalg.inv(Q.value) for i in range(n_r)]

for i in range(n_r):
  print(f'K{{{i+1}}}=', K[i])
# Out:
# True
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Aug 14 11:32:16 AM: Your problem has 24 variables, 64 constraints, and 0 parameters.
# (CVXPY) Aug 14 11:32:16 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 14 11:32:16 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 14 11:32:16 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 14 11:32:16 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 14 11:32:16 AM: Compiling problem (target solver=SCS).
# (CVXPY) Aug 14 11:32:16 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Aug 14 11:32:16 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 14 11:32:16 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 14 11:32:16 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 14 11:32:16 AM: Applying reduction SCS
# (CVXPY) Aug 14 11:32:16 AM: Finished problem compilation (took 5.143e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 14 11:32:16 AM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.6 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 18, constraints m: 40
# cones: 	  s: psd vars: 40, ssize: 4
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 135, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.02e-01  2.26e-02  3.71e-03  1.86e-03  1.00e-01  4.67e-02
#    250| 2.77e+15  9.67e+12  7.40e+14  3.70e+14  1.01e-03  5.23e-02
#    500| 3.69e+15  4.49e+10  1.27e+13  6.37e+12  7.35e-06  5.88e-02
#    750| 5.27e+17  1.60e+11  2.05e+11  1.03e+11  1.00e-06  6.62e-02
#   1000| 3.06e+14  4.48e+08  2.01e+11  1.00e+11  1.00e-06  7.14e-02
#   1250| 9.24e+14  8.88e+08  1.97e+11  9.83e+10  1.00e-06  7.70e-02
#   1500| 4.53e+14  3.30e+09  1.59e+11  7.97e+10  1.00e-06  8.30e-02
#   1750| 2.39e+14  4.20e+08  1.56e+11  7.79e+10  1.00e-06  8.87e-02
#   2000| 1.19e+14  3.38e+08  1.53e+11  7.63e+10  1.00e-06  9.45e-02
#   2250| 7.60e+13  2.97e+08  1.43e+11  7.15e+10  1.00e-06  1.00e-01
#   2500| 1.43e+14  2.06e+08  1.33e+11  6.63e+10  1.00e-06  1.07e-01
#   2750| 1.30e+15  2.17e+09  1.35e+11  6.73e+10  1.00e-06  1.14e-01
#   3000| 9.65e+13  2.70e+08  1.20e+11  6.02e+10  1.00e-06  1.28e-01
#   3250| 8.89e+13  1.81e+08  1.18e+11  5.89e+10  1.00e-06  1.38e-01
#   3500| 7.23e+13  6.17e+07  8.44e+10  4.22e+10  1.00e-06  1.47e-01
#   3750| 7.36e+13  1.05e+08  8.24e+10  4.12e+10  1.00e-06  1.53e-01
#   4000| 1.13e+14  8.27e+07  8.07e+10  4.03e+10  1.00e-06  1.63e-01
#   4250| 7.53e+15  6.84e+09  6.38e+10  3.19e+10  1.00e-06  1.72e-01
#   4500| 1.43e+14  9.56e+07  7.84e+10  3.92e+10  1.00e-06  1.79e-01
#   4750| 7.04e+13  5.52e+07  7.73e+10  3.87e+10  1.00e-06  1.87e-01
#   5000| 9.76e+13  7.46e+07  7.56e+10  3.78e+10  1.00e-06  1.95e-01
#   5250| 1.70e+15  5.00e+08  7.61e+10  3.80e+10  1.00e-06  2.01e-01
#   5500| 7.96e+13  7.47e+07  7.32e+10  3.66e+10  1.00e-06  2.06e-01
#   5750| 3.50e+04  9.11e-03  8.62e-01  4.31e-01  1.00e-06  2.12e-01
#   6000| 7.79e+13  6.87e+07  5.67e+10  2.84e+10  1.00e-06  2.17e-01
#   6250| 8.43e+13  1.10e+08  5.20e+10  2.60e+10  1.00e-06  2.25e-01
#   6500| 7.66e+13  5.66e+07  3.21e+10  1.60e+10  1.00e-06  2.30e-01
#   6750| 8.05e+13  7.24e+07  2.98e+10  1.49e+10  1.00e-06  2.36e-01
#   7000| 8.08e+13  1.73e+08  1.73e+10  8.66e+09  1.00e-06  2.42e-01
#   7250| 4.98e+16  1.60e+10  3.68e+10  1.84e+10  1.00e-06  2.48e-01
#   7500| 7.93e+13  1.98e+07  8.30e+09  4.15e+09  1.00e-06  2.53e-01
#   7750| 8.29e+13  9.46e+06  4.20e+09  2.10e+09  1.00e-06  2.60e-01
#   7925| 2.70e-06  2.84e-13  3.31e-15  1.66e-15  1.00e-06  2.65e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 2.66e-01s = setup: 2.94e-03s + solve: 2.63e-01s
# 	 lin-sys: 1.30e-02s, cones: 1.77e-01s, accel: 2.23e-03s
# ------------------------------------------------------------------
# objective = 0.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 14 11:32:16 AM: Problem status: optimal
# (CVXPY) Aug 14 11:32:16 AM: Optimal value: 0.000e+00
# (CVXPY) Aug 14 11:32:16 AM: Compilation took 5.143e-02 seconds
# (CVXPY) Aug 14 11:32:16 AM: Solver (including time spent in interface) took 3.062e-01 seconds
# K{1}= [[1214.1588337   281.95417737    5.84476041   61.99847439]]
# K{2}= [[603.77979209 138.92406918   2.90808056  41.38731   ]]
