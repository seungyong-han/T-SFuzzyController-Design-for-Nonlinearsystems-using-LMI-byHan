# %%
import cvxpy as cp
import numpy as np

# given parameters
m = 0.22;
M = 1.3282;
f0 = 22.915;
f1 = 0.007056;
l = 0.304;
J = 0.004963;
g = 9.8;

# determined domain
a = np.pi/3  # x1 \in [-a a]
b = 1        # x2 \in [-b b]
Premise_var_x1 = np.array([[-a, 0, a]])
Premise_var_x2 = np.array([[-b, b]])

n_r = np.size(Premise_var_x1)*np.size(Premise_var_x2)  # number of rules
n_s = 4  # size of A[i] matrix
n_u = 1  # size of B[i] matrix

# Define A and B matrices
A = []
B = []

A = []
for i in range(np.size(Premise_var_x1)):
  for j in range(np.size(Premise_var_x2)):
    x1 = Premise_var_x1[0,i]
    x2 = Premise_var_x2[0,j]
    if x1 == 0:
      ad = (M+m)*(J+m*l**2) - (m**2*l**2);
      a21d = (M+m)*m*g*(l/a);
      a22d = -f1*(M+m)/a;
      a24d = f0*m*(l/a);
      a41d = -m**2*g*(l**2/a);
      a42d = f1*m*(l/a);
      a44d = -f0*(J+m*l**2)/a;
      b2d = -m*(l/a);
      b4d = (J+m*l**2)/a;
    else:
      ad = (M+m)*(J+m*l**2)-m**2*l**2*np.cos(x1)**2
      a21d = (np.sin(x1)/x1)*(M+m)*m*g*(l/ad)
      a22d = (-f1*(M+m)-(m**2*l**2*x2*np.sin(x1)*np.cos(x1)))/ad
      a24d = f0*m*l*np.cos(x1)/ad
      a41d = -(np.sin(x1)*np.cos(x1)/x1)*((m**2*g*l**2)/ad)
      a42d = (f1*m*l*np.cos(x1)+((J+m*l**2)*(m*l*x2)*np.sin(x1)))/ad
      a44d = -f0*((J+m*l**2)/ad)
      b2d = -m*l*np.cos(x1)/ad
      b4d = (J+m*l**2)/ad

    A.append(np.array([[0, 1, 0, 0],
                  [a21d, a22d, 0, a24d],
                  [0, 0, 0, 1],
                  [a41d, a42d, 0, a44d]]))

    B.append(np.array([[0],
                    [b2d],
                    [0],
                    [b4d]]))


# decision variables
Q = cp.Variable((n_s, n_s), symmetric=True)
Y = [cp.Variable((n_u, n_s)) for _ in range(n_r)]
I = np.identity(n_s)
#gamma = cp.Variable((1, 1))
# LMI constraints
constraints = []

# LMI condition for stabilization of each sub system
for i in range(n_r):
    Ai = A[i]
    Bi = B[i]
    constraints.append((Ai @ Q + Q @ Ai.T + Bi @ Y[i] + Y[i].T @ Bi.T) << 0)

# LMI condition for stabilization of joint systems (refer [1])
# case 1
for j in range(1, n_r):
    Ai = A[0]
    Aj = A[j]
    Bi = B[0]
    Bj = B[j]
    constraint_lhs = (Ai @ Q + Q @ Ai.T + Bi @ Y[j] + Y[j].T @ Bi.T) / 2
    constraint_rhs = (Aj @ Q + Q @ Aj.T + Bj @ Y[0] + Y[0].T @ Bj.T) / 2
    constraints.append(constraint_lhs + constraint_rhs << 0)

# case 2
for j in range(2, n_r):
    Ai = A[1]
    Aj = A[j]
    Bi = B[1]
    Bj = B[j]
    constraint_lhs = (Ai @ Q + Q @ Ai.T + Bi @ Y[j] + Y[j].T @ Bi.T) / 2
    constraint_rhs = (Aj @ Q + Q @ Aj.T + Bj @ Y[1] + Y[1].T @ Bj.T) / 2
    constraints.append(constraint_lhs + constraint_rhs << 0)

# case 3
for j in range(3, n_r):
    Ai = A[2]
    Aj = A[j]
    Bi = B[2]
    Bj = B[j]
    constraint_lhs = (Ai @ Q + Q @ Ai.T + Bi @ Y[j] + Y[j].T @ Bi.T) / 2
    constraint_rhs = (Aj @ Q + Q @ Aj.T + Bj @ Y[2] + Y[2].T @ Bj.T) / 2
    constraints.append(constraint_lhs + constraint_rhs << 0)

# Positive semidefinite constraint on Q
constraints.append(Q - 0.1*I>> 0) # 0.1 is for avoiding numerical problems

problem = cp.Problem(cp.Minimize(0), constraints)
print(problem.is_qp())
problem.solve(verbose = True)  # you can choose SDP solvers (recommend "SCS" solver)


ch = [c.dual_value for c in constraints]

K = [Y[i].value @ np.linalg.inv(Q.value) for i in range(n_r)]

for i in range(n_r):
  print(f'K{{{i+1}}}=', K[i])
# Out:
# True
# ===============================================================================
#                                      CVXPY
#                                      v1.5.2
# ===============================================================================
# (CVXPY) Aug 14 11:55:19 AM: Your problem has 40 variables, 304 constraints, and 0 parameters.
# (CVXPY) Aug 14 11:55:19 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 14 11:55:19 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 14 11:55:19 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Aug 14 11:55:19 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 14 11:55:19 AM: Compiling problem (target solver=SCS).
# (CVXPY) Aug 14 11:55:19 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Aug 14 11:55:19 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 14 11:55:19 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 14 11:55:19 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 14 11:55:19 AM: Applying reduction SCS
# (CVXPY) Aug 14 11:55:19 AM: Finished problem compilation (took 1.144e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 14 11:55:19 AM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.6 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 34, constraints m: 190
# cones: 	  s: psd vars: 190, ssize: 19
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 808, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 9.99e-02  4.20e-02  8.17e-03  4.09e-03  1.00e-01  4.11e-02
#    250| 3.05e+15  3.58e+13  3.28e+15  1.64e+15  3.05e-04  6.99e-02
#    500| 2.69e+15  1.66e+11  1.15e+13  5.73e+12  1.00e-06  9.48e-02
#    750| 1.33e+15  3.15e+10  2.73e+12  1.36e+12  1.00e-06  1.21e-01
#   1000| 1.11e+15  1.34e+10  1.42e+12  7.12e+11  1.00e-06  1.45e-01
#   1250| 7.57e+14  1.23e+10  1.19e+12  5.93e+11  1.00e-06  1.68e-01
#   1500| 2.67e+14  9.94e+09  9.74e+11  4.87e+11  1.00e-06  1.93e-01
#   1750| 3.69e+14  1.00e+10  1.00e+12  5.01e+11  1.00e-06  2.16e-01
#   2000| 2.50e+14  8.07e+09  8.86e+11  4.43e+11  1.00e-06  2.38e-01
#   2250| 2.83e+14  7.65e+09  5.28e+11  2.64e+11  1.00e-06  2.61e-01
#   2500| 2.62e+14  4.40e+09  4.85e+11  2.43e+11  1.00e-06  2.85e-01
#   2750| 2.24e+14  3.82e+09  3.87e+11  1.94e+11  1.00e-06  3.10e-01
#   3000| 2.22e+14  3.22e+09  3.58e+11  1.79e+11  1.00e-06  3.56e-01
#   3250| 2.21e+14  3.52e+09  3.86e+11  1.93e+11  1.00e-06  3.96e-01
#   3500| 5.17e+14  3.25e+09  3.05e+11  1.52e+11  1.00e-06  4.39e-01
#   3750| 2.20e+14  2.39e+09  2.81e+11  1.40e+11  1.00e-06  4.77e-01
#   4000| 2.81e+14  3.32e+09  8.00e+10  4.00e+10  1.00e-06  5.31e-01
#   4250| 2.71e+05  8.23e-01  5.09e-02  2.55e-02  1.00e-06  5.67e-01
#   4500| 2.19e+14  7.28e+08  1.04e+10  5.20e+09  1.00e-06  6.16e-01
#   4700| 2.45e+00  1.53e-11  5.93e-14  2.97e-14  1.00e-06  6.43e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.44e-01s = setup: 6.56e-03s + solve: 6.37e-01s
# 	 lin-sys: 3.32e-02s, cones: 5.37e-01s, accel: 3.27e-03s
# ------------------------------------------------------------------
# objective = 0.000000
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 14 11:55:20 AM: Problem status: optimal
# (CVXPY) Aug 14 11:55:20 AM: Optimal value: 0.000e+00
# (CVXPY) Aug 14 11:55:20 AM: Compilation took 1.144e-01 seconds
# (CVXPY) Aug 14 11:55:20 AM: Solver (including time spent in interface) took 6.684e-01 seconds
# K{1}= [[160.00237196  41.94243039   1.74557348  57.68074125]]
# K{2}= [[161.17644047  42.72651613   1.77527554  58.37913544]]
# K{3}= [[607.6785384  182.70637164   6.40284217 159.81816265]]
# K{4}= [[613.97890776 178.49036058   6.49907699 160.62573939]]
# K{5}= [[169.80604397  47.83264729   1.98638712  63.67989567]]
# K{6}= [[169.40514833  47.6316946    1.98509784  63.6627364 ]]

# %%
for i in range(6):
  [a, b] = np.linalg.eig(A[0]+B[0]*K[i])
  print(a)
  [a, b] = np.linalg.eig(A[1]+B[1]*K[i])
  print(a)
  [a, b] = np.linalg.eig(A[2]+B[2]*K[i])
  print(a)
  [a, b] = np.linalg.eig(A[3]+B[3]*K[i])
  print(a)
  [a, b] = np.linalg.eig(A[4]+B[4]*K[i])
  print(a)
  [a, b] = np.linalg.eig(A[5]+B[5]*K[i])
  print(a)

# print( np.linalg.eig(A[0]+B[0]*K[1]))
# print( np.linalg.eig(A[0]+B[0]*K[2]))
# print( np.linalg.eig(A[0]+B[0]*K[3]))
# print( np.linalg.eig(A[0]+B[0]*K[4]))
# print( np.linalg.eig(A[0]+B[0]*K[5]))
# Out:
# [-3.05984279+7.2411132j -3.05984279-7.2411132j -7.91978152+0.j
#  -0.05081765+0.j       ]
# [-3.0507487 +7.2903235j -3.0507487 -7.2903235j -7.83614539+0.j
#  -0.05081768+0.j       ]
# [-0.88530109+2.87620128j -0.88530109-2.87620128j -0.0393817 +0.04944843j
#  -0.0393817 -0.04944843j]
# [-0.88530109+2.87620128j -0.88530109-2.87620128j -0.0393817 +0.04944843j
#  -0.0393817 -0.04944843j]
# [-3.0507487 +7.2903235j -3.0507487 -7.2903235j -7.83614539+0.j
#  -0.05081768+0.j       ]
# [-3.05984279+7.2411132j -3.05984279-7.2411132j -7.91978152+0.j
#  -0.05081765+0.j       ]
# [-3.05911161+7.20678198j -3.05911161-7.20678198j -8.14626557+0.j
#  -0.05065572+0.j        ]
# [-3.0514536 +7.25550683j -3.0514536 -7.25550683j -8.05975727+0.j
#  -0.05065575+0.j        ]
# [-0.90142348+2.88331855j -0.90142348-2.88331855j -0.03986272+0.04943624j
#  -0.03986272-0.04943624j]
# [-0.90142348+2.88331855j -0.90142348-2.88331855j -0.03986272+0.04943624j
